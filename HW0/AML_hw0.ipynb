# %%
# 1. Find and download the Iris Flowers dataset from the UCIrvine Machine Learning datasets 
#    archive at http://archive.ics.uci.edu/ml/datasets.html 
#    Hint: The iris.names ﬁle describes the structure of the dataset. 
#    How many features/attributes are there per sample? How many different species are there,
#    and how many samples of each species did Ander3son record?

# Answers: 1) Four features/attributes.
#          2) Three different species.
#          3) 50 samples of each species.

# %%
import csv


# Solution 1:
begin = 0
end = 4
dataSet=[]
labels=[]
with open('C:/Users/AngZhou/Desktop/Cornell_Course/AML/HW/HW0/Iris_flowers_dataset/iris.data.txt', 'rb') as f:
    for row in csv.reader(f):
        # print row
        if row != []:
            dataSet.append(map(float,row[begin:end]))
            labels.append(row[end])
print dataSet
print labels

# Solution 2:
# dataSet=[]
# labees=[]
# with open('C:\Users\AngZhou\Desktop\Cornell_Course\AML\HW\Iris_flowers_dataset\iris.data.txt', 'rb') as f:
    # for line in f:
        # array=line.rstrip().split(',')
        # if len(array) == 5:
            # dataSet.append(array[0:4])
            # labels.append(array[4])
# print dataSet
# print labees
# Out:
# [[5.1, 3.5, 1.4, 0.2], [4.9, 3.0, 1.4, 0.2], [4.7, 3.2, 1.3, 0.2], [4.6, 3.1, 1.5, 0.2], [5.0, 3.6, 1.4, 0.2], [5.4, 3.9, 1.7, 0.4], [4.6, 3.4, 1.4, 0.3], [5.0, 3.4, 1.5, 0.2], [4.4, 2.9, 1.4, 0.2], [4.9, 3.1, 1.5, 0.1], [5.4, 3.7, 1.5, 0.2], [4.8, 3.4, 1.6, 0.2], [4.8, 3.0, 1.4, 0.1], [4.3, 3.0, 1.1, 0.1], [5.8, 4.0, 1.2, 0.2], [5.7, 4.4, 1.5, 0.4], [5.4, 3.9, 1.3, 0.4], [5.1, 3.5, 1.4, 0.3], [5.7, 3.8, 1.7, 0.3], [5.1, 3.8, 1.5, 0.3], [5.4, 3.4, 1.7, 0.2], [5.1, 3.7, 1.5, 0.4], [4.6, 3.6, 1.0, 0.2], [5.1, 3.3, 1.7, 0.5], [4.8, 3.4, 1.9, 0.2], [5.0, 3.0, 1.6, 0.2], [5.0, 3.4, 1.6, 0.4], [5.2, 3.5, 1.5, 0.2], [5.2, 3.4, 1.4, 0.2], [4.7, 3.2, 1.6, 0.2], [4.8, 3.1, 1.6, 0.2], [5.4, 3.4, 1.5, 0.4], [5.2, 4.1, 1.5, 0.1], [5.5, 4.2, 1.4, 0.2], [4.9, 3.1, 1.5, 0.1], [5.0, 3.2, 1.2, 0.2], [5.5, 3.5, 1.3, 0.2], [4.9, 3.1, 1.5, 0.1], [4.4, 3.0, 1.3, 0.2], [5.1, 3.4, 1.5, 0.2], [5.0, 3.5, 1.3, 0.3], [4.5, 2.3, 1.3, 0.3], [4.4, 3.2, 1.3, 0.2], [5.0, 3.5, 1.6, 0.6], [5.1, 3.8, 1.9, 0.4], [4.8, 3
# ...

# %%
# %matplotlib inline

from matplotlib import pyplot as plt 
import numpy as np
npDataSet = np.array(dataSet)
colors=[]
# assuming the obs haven't been sorted:
for i,rec in enumerate(npDataSet):
    if labels[i]=='Iris-setosa':
        colors.append('r')
    elif labels[i]=='Iris-versicolor':
        colors.append('g')
    else:
        colors.append('b')

fields_vec=[]
for i in range(len(npDataSet[0])):
    fields_vec.append(npDataSet[:,i])

plt.figure(1,figsize=(18,18))
plt.figure()
plt.figure(1,figsize=(1,1))
label_names=['Sepal length in cm','Sepal width in cm','Petal length in cm','Petal width in cm']
for a in range(4):
    for b in range(4):
        if a!=b:
            plt.subplot(4,4,a*4+(b+1))
            plt.scatter(fields_vec[b], fields_vec[a], c=colors)
            plt.xlabel(label_names[b])
            plt.ylabel(label_names[a])
        else:
            plt.subplot(4,4,a*4+(b+1))
            plt.text(0.08, 0.48, label_names[a], dict(size=20))

plt.savefig("plot.png")
